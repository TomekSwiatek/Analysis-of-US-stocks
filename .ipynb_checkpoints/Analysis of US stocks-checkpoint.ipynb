# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Upload the file with the data of the analyzed stock

# %%
#plik = pd.ExcelFile('Apple.xlsx') #loading file .xls
plik = pd.ExcelFile('Nvidia.xlsx') #loading file .xls
df_temp = plik.parse() #converting excel table into data frame
df_temp
# Out:
#                 Stock  Date  Temp1    Temp2  Revenue USD Mil  Gross Margin %  \
# 0   NVIDIA Corp  NVDA  2012    NaN  2012-01             3998            51.4
# 1   NVIDIA Corp  NVDA  2013    NaN  2013-01             4280            52.0
# 2   NVIDIA Corp  NVDA  2014    NaN  2014-01             4130            54.9
# 3   NVIDIA Corp  NVDA  2015    NaN  2015-01             4682            55.5
# 4   NVIDIA Corp  NVDA  2016    NaN  2016-01             5010            56.1
# 5   NVIDIA Corp  NVDA  2017    NaN  2017-01             6910            58.8
# 6   NVIDIA Corp  NVDA  2018    NaN  2018-01             9714            59.9
# 7   NVIDIA Corp  NVDA  2019    NaN  2019-01            11716            61.2
# 8   NVIDIA Corp  NVDA  2020    NaN  2020-01            10918            62.0
# 9   NVIDIA Corp  NVDA  2021    NaN  2021-01            16675            62.3
# 10  NVIDIA Corp  NVDA  2022    NaN      TTM            16675            62.3
#
#     Operating Income USD Mil  Operating Margin %  Net Income USD Mil  \
# 0                        648                16.2                 581
# 1                        648                15.1                 563
# 2                        496                12.0                 440
# 3                        759                16.2                 631
# 4                        878                17.5                 614
# 5                       1937                28.0                1666
# 6                       3210                33.0                3047
# 7                       3804                32.5                4141
# 8                       2846                26.1                2796
# 9                       4532                27.2                4332
# 10                      4532                27.2                4332
#
#     Earnings Per Share USD  ...  Days Inventory  Payables Period  \
# 0                     0.94  ...           64.47            58.40
# 1                     0.90  ...           67.53            61.44
# 2                     0.74  ...           79.12            66.71
# 3                     1.12  ...           76.32            54.14
# 4                     1.08  ...           74.77            48.90
# 5                     2.57  ...           77.69            50.06
# 6                     4.82  ...           74.56            50.69
# 7                     6.63  ...           95.21            44.45
# 8                     4.52  ...          112.31            52.68
# 9                     6.90  ...           81.53            54.88
# 10                    6.90  ...           81.53            54.88
#
#     Cash Conversion Cycle  Receivables Turnover  Inventory Turnover  \
# 0                   37.34                 11.67                5.66
# 1                   39.79                 10.83                5.40
# 2                   51.32                  9.38                4.61
# 3                   57.27                 10.40                4.78
# 4                   61.52                 10.24                4.88
# 5                   62.78                 10.38                4.70
# 6                   63.15                  9.29                4.90
# 7                   92.64                  8.71                3.83
# 8                  111.13                  7.09                3.25
# 9                   71.37                  8.16                4.48
# 10                  71.37                  8.16                4.48
#
#     Fixed Assets Turnover  Asset Turnover  Temp19  Book Value  \
# 0                    7.08            0.80     NaN     3172.40
# 1                    7.53            0.72     NaN     3525.00
# 2                    7.13            0.60     NaN     3337.95
# 3                    8.21            0.65     NaN     3834.03
# 4                    9.79            0.69     NaN     4318.71
# 5                   14.00            0.80     NaN     5516.50
# 6                   12.80            0.92     NaN     5340.40
# 7                    9.76            0.96     NaN     8506.25
# 8                    5.91            0.71     NaN    10258.80
# 9                    6.48            0.72     NaN    12817.48
# 10                   6.48            0.72     NaN    14205.36
#
#     Year-end Yield %
# 0               1.20
# 1               0.45
# 2               0.29
# 3               0.46
# 4               0.26
# 5               0.57
# 6               0.61
# 7               0.64
# 8               0.64
# 9                NaN
# 10               NaN
#
# [11 rows x 108 columns]

# %% [markdown]
# ## Data modification

# %%
df_temp=df_temp.drop(columns=['Temp1','Temp2','Temp3','Temp4','Temp5','Temp6','Temp7','Temp8','Temp9','Temp10',\
                              'Temp11','Temp12','Temp13','Temp14','Temp15','Temp16','Temp17','Temp18','Temp19'],\
                     axis=1) # removing unnecessary columns
#df=df_temp.drop(0, axis=0)
df=df_temp

# %% [markdown]
# ## Initial data analysis

# %%
df
# Out:
#                 Stock  Date  Revenue USD Mil  Gross Margin %  \
# 0   NVIDIA Corp  NVDA  2012             3998            51.4
# 1   NVIDIA Corp  NVDA  2013             4280            52.0
# 2   NVIDIA Corp  NVDA  2014             4130            54.9
# 3   NVIDIA Corp  NVDA  2015             4682            55.5
# 4   NVIDIA Corp  NVDA  2016             5010            56.1
# 5   NVIDIA Corp  NVDA  2017             6910            58.8
# 6   NVIDIA Corp  NVDA  2018             9714            59.9
# 7   NVIDIA Corp  NVDA  2019            11716            61.2
# 8   NVIDIA Corp  NVDA  2020            10918            62.0
# 9   NVIDIA Corp  NVDA  2021            16675            62.3
# 10  NVIDIA Corp  NVDA  2022            16675            62.3
#
#     Operating Income USD Mil  Operating Margin %  Net Income USD Mil  \
# 0                        648                16.2                 581
# 1                        648                15.1                 563
# 2                        496                12.0                 440
# 3                        759                16.2                 631
# 4                        878                17.5                 614
# 5                       1937                28.0                1666
# 6                       3210                33.0                3047
# 7                       3804                32.5                4141
# 8                       2846                26.1                2796
# 9                       4532                27.2                4332
# 10                      4532                27.2                4332
#
#     Earnings Per Share USD  Dividends USD  Payout Ratio % *  ...  \
# 0                     0.94           0.00               0.0  ...
# 1                     0.90           0.07               0.0  ...
# 2                     0.74           0.31              39.0  ...
# 3                     1.12           0.34              33.3  ...
# 4                     1.08           0.39              34.1  ...
# 5                     2.57           0.26              11.8  ...
# 6                     4.82           0.57              13.9  ...
# 7                     6.63           0.61               8.0  ...
# 8                     4.52           0.64              16.4  ...
# 9                     6.90           0.64              10.5  ...
# 10                    6.90           0.64               9.2  ...
#
#     Days Sales Outstanding  Days Inventory  Payables Period  \
# 0                    31.27           64.47            58.40
# 1                    33.70           67.53            61.44
# 2                    38.91           79.12            66.71
# 3                    35.08           76.32            54.14
# 4                    35.65           74.77            48.90
# 5                    35.15           77.69            50.06
# 6                    39.28           74.56            50.69
# 7                    41.89           95.21            44.45
# 8                    51.50          112.31            52.68
# 9                    44.72           81.53            54.88
# 10                   44.72           81.53            54.88
#
#     Cash Conversion Cycle  Receivables Turnover  Inventory Turnover  \
# 0                   37.34                 11.67                5.66
# 1                   39.79                 10.83                5.40
# 2                   51.32                  9.38                4.61
# 3                   57.27                 10.40                4.78
# 4                   61.52                 10.24                4.88
# 5                   62.78                 10.38                4.70
# 6                   63.15                  9.29                4.90
# 7                   92.64                  8.71                3.83
# 8                  111.13                  7.09                3.25
# 9                   71.37                  8.16                4.48
# 10                  71.37                  8.16                4.48
#
#     Fixed Assets Turnover  Asset Turnover  Book Value  Year-end Yield %
# 0                    7.08            0.80     3172.40              1.20
# 1                    7.53            0.72     3525.00              0.45
# 2                    7.13            0.60     3337.95              0.29
# 3                    8.21            0.65     3834.03              0.46
# 4                    9.79            0.69     4318.71              0.26
# 5                   14.00            0.80     5516.50              0.57
# 6                   12.80            0.92     5340.40              0.61
# 7                    9.76            0.96     8506.25              0.64
# 8                    5.91            0.71    10258.80              0.64
# 9                    6.48            0.72    12817.48               NaN
# 10                   6.48            0.72    14205.36               NaN
#
# [11 rows x 89 columns]

# %%
df[:][['Net Income USD Mil']]
# Out:
#     Net Income USD Mil
# 0                  581
# 1                  563
# 2                  440
# 3                  631
# 4                  614
# 5                 1666
# 6                 3047
# 7                 4141
# 8                 2796
# 9                 4332
# 10                4332

# %%
print ('Company name:',df.Stock.unique())
# Out:
# Company name: ['NVIDIA Corp  NVDA']

# %%
print ('Number of years:',df.shape[0],'\n')
print ('Number of attributes:',df.shape[1])
# Out:
# Number of years: 11
#
# Number of attributes: 89

# %%
#Type of atrributes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 89 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Stock                                      11 non-null     object
#  1   Date                                       11 non-null     int64
#  2   Revenue USD Mil                            11 non-null     int64
#  3   Gross Margin %                             11 non-null     float64
#  4   Operating Income USD Mil                   11 non-null     int64
#  5   Operating Margin %                         11 non-null     float64
#  6   Net Income USD Mil                         11 non-null     int64
#  7   Earnings Per Share USD                     11 non-null     float64
#  8   Dividends USD                              11 non-null     float64
#  9   Payout Ratio % *                           11 non-null     float64
#  10  Shares Mil                                 11 non-null     int64
#  11  Book Value Per Share * USD                 11 non-null     float64
#  12  Operating Cash Flow USD Mil                11 non-null     int64
#  13  Cap Spending USD Mil                       11 non-null     int64
#  14  Free Cash Flow USD Mil                     11 non-null     int64
#  15  Free Cash Flow Per Share * USD             11 non-null     float64
#  16  Working Capital USD Mil                    11 non-null     int64
#  17  Margins % of Sales - Revenue %             11 non-null     int64
#  18  COGS %                                     11 non-null     float64
#  19  Gross Margin %.1                           11 non-null     float64
#  20  SG&A %                                     11 non-null     float64
#  21  R&D %                                      11 non-null     float64
#  22  Other %                                    11 non-null     int64
#  23  Operating Margin %.1                       11 non-null     float64
#  24  Net Int Inc & Other %                      11 non-null     float64
#  25  EBT Margin %                               11 non-null     float64
#  26  Tax Rate %                                 11 non-null     float64
#  27  Net Margin %                               11 non-null     float64
#  28  Asset Turnover (Average) %                 11 non-null     float64
#  29  Return on Assets %                         11 non-null     float64
#  30  Financial Leverage (Average) %             11 non-null     float64
#  31  Return on Equity %                         11 non-null     float64
#  32  Return on Invested Capital %               11 non-null     float64
#  33  Interest Coverage %                        11 non-null     float64
#  34  Growth Revenue % Year over Year            11 non-null     float64
#  35  Growth Revenue % 3-Year Average            11 non-null     float64
#  36  Growth Revenue % 5-Year Average            11 non-null     float64
#  37  Growth Revenue % 10-Year Average           11 non-null     float64
#  38  Growth Operating Income % Year over Year   11 non-null     float64
#  39  Growth Operating Income % 3-Year Average   11 non-null     float64
#  40  Growth Operating Income % 5-Year Average   11 non-null     float64
#  41  Growth Operating Income % 10-Year Average  11 non-null     float64
#  42  Growth Net Income % Year over Year         11 non-null     float64
#  43  Growth Net Income % 3-Year Average         11 non-null     float64
#  44  Growth Net Income % 5-Year Average         11 non-null     float64
#  45  Growth Net Income % 10-Year Average        11 non-null     float64
#  46  Growth EPS % Year over Year                11 non-null     float64
#  47  Growth EPS % 3-Year Average                11 non-null     float64
#  48  Growth EPS % 5-Year Average                11 non-null     float64
#  49  Growth EPS % 10-Year Average               11 non-null     float64
#  50  Operating Cash Flow Growth % YOY           11 non-null     float64
#  51  Free Cash Flow Growth % YOY                11 non-null     float64
#  52  Cap Ex as a % of Sales                     11 non-null     float64
#  53  Free Cash Flow/Sales %                     11 non-null     float64
#  54  Free Cash Flow/Net Income                  11 non-null     float64
#  55  Cash & Short-Term Investments %            11 non-null     float64
#  56  Accounts Receivable %                      11 non-null     float64
#  57  Inventory %                                11 non-null     float64
#  58  Other Current Assets %                     11 non-null     float64
#  59  Total Current Assets %                     11 non-null     float64
#  60  Net PP&E %                                 11 non-null     float64
#  61  Intangibles %                              11 non-null     float64
#  62  Other Long-Term Assets %                   11 non-null     float64
#  63  Total Assets %                             11 non-null     int64
#  64  Accounts Payable %                         11 non-null     float64
#  65  Short-Term Debt %                          11 non-null     float64
#  66  Taxes Payable %                            11 non-null     float64
#  67  Accrued Liabilities %                      11 non-null     float64
#  68  Other Short-Term Liabilities %             11 non-null     float64
#  69  Total Current Liabilities %                11 non-null     float64
#  70  Long-Term Debt %                           11 non-null     float64
#  71  Other Long-Term Liabilities %              11 non-null     float64
#  72  Total Liabilities %                        11 non-null     float64
#  73  Total Stockholders' Equity %               11 non-null     float64
#  74  Total Liabilities & Equity %               11 non-null     int64
#  75  Current Ratio                              11 non-null     float64
#  76  Quick Ratio                                11 non-null     float64
#  77  Financial Leverage                         11 non-null     float64
#  78  Debt/Equity                                11 non-null     float64
#  79  Days Sales Outstanding                     11 non-null     float64
#  80  Days Inventory                             11 non-null     float64
#  81  Payables Period                            11 non-null     float64
#  82  Cash Conversion Cycle                      11 non-null     float64
#  83  Receivables Turnover                       11 non-null     float64
#  84  Inventory Turnover                         11 non-null     float64
#  85  Fixed Assets Turnover                      11 non-null     float64
#  86  Asset Turnover                             11 non-null     float64
#  87  Book Value                                 11 non-null     float64
#  88  Year-end Yield %                           9 non-null      float64
# dtypes: float64(75), int64(13), object(1)
# memory usage: 7.8+ KB

# %%
#Check data NaN
df.isnull().sum()
# Out:
# Stock                       0
# Date                        0
# Revenue USD Mil             0
# Gross Margin %              0
# Operating Income USD Mil    0
#                            ..
# Inventory Turnover          0
# Fixed Assets Turnover       0
# Asset Turnover              0
# Book Value                  0
# Year-end Yield %            2
# Length: 89, dtype: int64

# %%
df.notnull().sum()
# Out:
# Stock                       11
# Date                        11
# Revenue USD Mil             11
# Gross Margin %              11
# Operating Income USD Mil    11
#                             ..
# Inventory Turnover          11
# Fixed Assets Turnover       11
# Asset Turnover              11
# Book Value                  11
# Year-end Yield %             9
# Length: 89, dtype: int64

# %%
#Convert NaN to zero
df.fillna(value=0, inplace=True)

# %%
#Check duplicates
df.duplicated().sum()
# Out:
# 0

# %%
#Remove duplicates
if df.duplicated().sum()>0:
    df.drop_duplicates();

# %%
#Statistical indicators
df.describe()
# Out:
#               Date  Revenue USD Mil  Gross Margin %  Operating Income USD Mil  \
# count    11.000000        11.000000       11.000000                 11.000000
# mean   2017.000000      8609.818182       57.854545               2208.181818
# std       3.316625      4874.939934        4.077588               1627.891324
# min    2012.000000      3998.000000       51.400000                496.000000
# 25%    2014.500000      4481.000000       55.200000                703.500000
# 50%    2017.000000      6910.000000       58.800000               1937.000000
# 75%    2019.500000     11317.000000       61.600000               3507.000000
# max    2022.000000     16675.000000       62.300000               4532.000000
#
#        Operating Margin %  Net Income USD Mil  Earnings Per Share USD  \
# count           11.000000           11.000000               11.000000
# mean            22.818182         2103.909091                3.374545
# std              7.522741         1658.017760                2.623804
# min             12.000000          440.000000                0.740000
# 25%             16.200000          597.500000                1.010000
# 50%             26.100000         1666.000000                2.570000
# 75%             27.600000         3594.000000                5.725000
# max             33.000000         4332.000000                6.900000
#
#        Dividends USD  Payout Ratio % *  Shares Mil  ...  \
# count      11.000000         11.000000   11.000000  ...
# mean        0.406364         16.018182  613.454545  ...
# std         0.233592         13.529953   26.808072  ...
# min         0.000000          0.000000  563.000000  ...
# 25%         0.285000          8.600000  605.500000  ...
# 50%         0.390000         11.800000  625.000000  ...
# 75%         0.625000         24.850000  628.000000  ...
# max         0.640000         39.000000  649.000000  ...
#
#        Days Sales Outstanding  Days Inventory  Payables Period  \
# count               11.000000       11.000000        11.000000
# mean                39.260909       80.458182        54.293636
# std                  5.988580       13.232286         6.183140
# min                 31.270000       64.470000        44.450000
# 25%                 35.115000       74.665000        50.375000
# 50%                 38.910000       77.690000        54.140000
# 75%                 43.305000       81.530000        56.640000
# max                 51.500000      112.310000        66.710000
#
#        Cash Conversion Cycle  Receivables Turnover  Inventory Turnover  \
# count              11.000000             11.000000           11.000000
# mean               65.425455              9.482727            4.633636
# std                21.538536              1.367056            0.663796
# min                37.340000              7.090000            3.250000
# 25%                54.295000              8.435000            4.480000
# 50%                62.780000              9.380000            4.700000
# 75%                71.370000             10.390000            4.890000
# max               111.130000             11.670000            5.660000
#
#        Fixed Assets Turnover  Asset Turnover    Book Value  Year-end Yield %
# count              11.000000       11.000000     11.000000         11.000000
# mean                8.651818        0.753636   6802.989091          0.465455
# std                 2.674423        0.108745   4006.574472          0.337472
# min                 5.910000        0.600000   3172.400000          0.000000
# 25%                 6.780000        0.700000   3679.515000          0.275000
# 50%                 7.530000        0.720000   5340.400000          0.460000
# 75%                 9.775000        0.800000   9382.525000          0.625000
# max                14.000000        0.960000  14205.360000          1.200000
#
# [8 rows x 88 columns]

# %%
df['Net Income USD Mil'].describe()
# Out:
# count      11.000000
# mean     2103.909091
# std      1658.017760
# min       440.000000
# 25%       597.500000
# 50%      1666.000000
# 75%      3594.000000
# max      4332.000000
# Name: Net Income USD Mil, dtype: float64

# %%
df[  df['Net Income USD Mil'] > df['Operating Cash Flow USD Mil']  ]
# Out:
#                Stock  Date  Revenue USD Mil  Gross Margin %  \
# 7  NVIDIA Corp  NVDA  2019            11716            61.2
#
#    Operating Income USD Mil  Operating Margin %  Net Income USD Mil  \
# 7                      3804                32.5                4141
#
#    Earnings Per Share USD  Dividends USD  Payout Ratio % *  ...  \
# 7                    6.63           0.61               8.0  ...
#
#    Days Sales Outstanding  Days Inventory  Payables Period  \
# 7                   41.89           95.21            44.45
#
#    Cash Conversion Cycle  Receivables Turnover  Inventory Turnover  \
# 7                  92.64                  8.71                3.83
#
#    Fixed Assets Turnover  Asset Turnover  Book Value  Year-end Yield %
# 7                   9.76            0.96     8506.25              0.64
#
# [1 rows x 89 columns]

# %% [markdown]
# ## Charts

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Date'],df['Revenue USD Mil'], color = 'lightgray', alpha=0.5, label = 'Revenue USD Mil')
plt.bar(df['Date'],df['Operating Income USD Mil'], color = 'darkgray', alpha=0.5, label = 'Operating Income USD Mil')
plt.bar(df['Date'],df['Net Income USD Mil'], color = 'gray', alpha=0.5, label = 'Net Income USD Mil')

plt.xticks(df['Date'])
 
plt.legend(frameon=False)
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Company results');

# %%
plt.figure(figsize=(20,8))
plt.subplot(1, 1, 1)

sns.set(font_scale=1.5, style="whitegrid")
ax = sns.lineplot(x='Date', y='Operating Cash Flow Growth % YOY', 
                  data=df, 
                  color='black', 
                  label = 'Operating Cash Flow Growth % YOY')
ax = sns.lineplot(x='Date', y='Free Cash Flow Growth % YOY', 
                  data=df, 
                  color='blue', 
                  label = 'Free Cash Flow Growth % YOY')

ax = sns.lineplot(x='Date', y='Payout Ratio % *', 
                  data=df, 
                  color='slategrey', 
                  label = 'Payout Ratio %')

ax = sns.lineplot(x='Date', y='Long-Term Debt %', 
                  data=df, 
                  color='firebrick', 
                  label = 'Long-Term Debt %')
ax = sns.lineplot(x='Date', y='Short-Term Debt %', 
                  data=df, 
                  color='lightcoral', 
                  label = 'Short-Term Debt %')

ax = sns.lineplot(x='Date', y='Gross Margin %', 
                  data=df, 
                  color='palegreen', 
                  label = 'Gross Margin %')
ax = sns.lineplot(x='Date', y='Operating Margin %', 
                  data=df, 
                  color='lime', 
                  label = 'Operating Margin %')
ax = sns.lineplot(x='Date', y='Net Margin %', 
                  data=df, 
                  color='olive', 
                  label = 'Net Margin %')
ax = sns.lineplot(x='Date', y='Return on Assets %', 
                  data=df, 
                  color='green', 
                  label = 'Return on Assets %')
ax = sns.lineplot(x='Date', y='Return on Equity %', 
                  data=df, 
                  color='aquamarine', 
                  label = 'Return on Equity %')

                  
ax.set_title('Financial basic values');
plt.xlabel('Date')
plt.ylabel('Value [%]')
plt.legend(frameon=False)

# %% [markdown]
# ## Indicators

# %%
#Book Value
for i in range(1,df.Date.count()):
    df.loc[0,'Change in book value %']=100
    df.loc[i,'Change in book value %']=round(((df.loc[i,'Book Value']- \
                                         df.loc[i-1,'Book Value']) \
                                         /df.loc[i-1,'Book Value'])*100,0)

#Increase in sales revenue
for i in range(1,df.Date.count()):
    df.loc[0,'Change in Revenue %']=100
    df.loc[i,'Change in Revenue %']=round(((df.loc[i,'Revenue USD Mil']- \
                                                           df.loc[i-1,'Revenue USD Mil']) \
                                                           /df.loc[i-1,'Revenue USD Mil'])*100,0)

#Increase 
for i in range(1,df.Date.count()):
    df.loc[0,'Change in Net Income %']=100
    df.loc[i,'Change in Net Income %']=round(((df.loc[i,'Net Income USD Mil']-df.loc[i-1,'Net Income USD Mil'])\
                                                            /df.loc[i-1,'Net Income USD Mil'])*100,0)

# %%
#Profitability
df['ROE %'] = df['Return on Equity %'] #best >20%
df['ROA %'] = df['Return on Assets %'] #best >10%
df['ROS %'] = df['Gross Margin %'] #best >10%
df['OM %'] = df['Operating Margin %'] #best >10%
df['NM %'] = df['Net Margin %'] #best >10%

# %%
#Liquidity
df['Current Ratio'] = df['Current Ratio'] #best >2
df['Cash Ratio %'] = round((df['Cash & Short-Term Investments %']/df['Short-Term Debt %'])*100,2) #best >20%
df['Working capital'] = round((df['Total Current Assets %']-df['Short-Term Debt %']),0) #best >0

# %%
#Activity
df['DSO'] = df['Days Sales Outstanding']
df['DI'] = df['Days Inventory']
df['PP'] = df['Payables Period']
df['Cash conversion cycle'] = round((df['DSO']+df['DI']-df['PP']),0) #best <0

# %%
#Debt
df['Longterm Debt/Equity Ratio'] = df['Debt/Equity'] #best <20%
df['Debt ratio (Total debt/assets)'] = round(((df['Long-Term Debt %']+df['Short-Term Debt %']) \
                                            /df['Total Assets %'])*100,2) #best <67%

# %%
#Property
df['1st degree of coverage'] = round((df["Total Stockholders' Equity %"]/\
                                      (df['Net PP&E %']+df['Intangibles %']+df['Other Long-Term Assets %'])),2) #best >0.6

# %%
#Cash flow
def flow(data):
        if data > 0: return 1
        else: return 0
        
df['Operating Cash Flow rate']=0        
df['Operating Cash Flow rate']=df['Operating Cash Flow USD Mil'].apply(flow) #best >0

df['Investing Cash Flow rate']=0        
df['Investing Cash Flow rate']=df['Cap Spending USD Mil'].apply(flow) #best <0

df['Finance Cash Flow rate']=0        
df['Finance Cash Flow rate']=df['Cap Spending USD Mil'].apply(flow) #best <0

df['Free cash flow rate']=0        
df['Free cash flow rate']=df['Free Cash Flow USD Mil'].apply(flow) #best >0

# %%
#Cash flow description

def flows(data):
        if ((data['Operating Cash Flow rate'] > 0) & \
        (data['Investing Cash Flow rate'] > 0) & \
        (data['Finance Cash Flow rate'] > 0)) : return 'I - (+++) rare situation, need to analyze cases'      
        elif ((data['Operating Cash Flow rate'] > 0) & \
        (data['Investing Cash Flow rate']) > 0 & \
        (data['Finance Cash Flow rate']) == 0): return 'II - (++-) restructuring process'    
        elif ((data['Operating Cash Flow rate'] > 0) & \
        (data['Investing Cash Flow rate']) == 0 & \
        (data['Finance Cash Flow rate']) == 0): return 'III - (+--) stable company, the best'    
        elif ((data['Operating Cash Flow rate'] == 0) & \
        (data['Investing Cash Flow rate']) == 0 & \
        (data['Finance Cash Flow rate']) == 0) : return 'IV - (---) bankrupt'    
        elif ((data['Operating Cash Flow rate'] < 0) & \
        (data['Investing Cash Flow rate']) > 0 & \
        (data['Finance Cash Flow rate']) > 0)  : return 'V - (-++) temporary problems'    
        elif ((data['Operating Cash Flow rate'] == 0) & \
        (data['Investing Cash Flow rate']) == 0 & \
        (data['Finance Cash Flow rate']) > 0)  : return 'VI - (--+) start-up, early stage of activity'    
        elif ((data['Operating Cash Flow rate'] == 0) & \
        (data['Investing Cash Flow rate']) > 0 & \
        (data['Finance Cash Flow rate']) == 0)   : return 'VII - (-+-) probable bankruptcy'    
        elif ((data['Operating Cash Flow rate'] > 0) & \
        (data['Investing Cash Flow rate']) == 0 & \
        (data['Finance Cash Flow rate']) == 0)  : return 'VIII - (+-+) after the start-up phase'                                 
        else: return 'Error'

df['Cash flow description']='0'      
df['Cash flow description']=df.apply(flows, axis=1)

# %%
df[['Date','Cash flow description']]
# Out:
#     Date                 Cash flow description
# 0   2012  III - (+ -) stable company, the best
# 1   2013  III - (+ -) stable company, the best
# 2   2014  III - (+ -) stable company, the best
# 3   2015  III - (+ -) stable company, the best
# 4   2016  III - (+ -) stable company, the best
# 5   2017  III - (+ -) stable company, the best
# 6   2018  III - (+ -) stable company, the best
# 7   2019  III - (+ -) stable company, the best
# 8   2020  III - (+ -) stable company, the best
# 9   2021  III - (+ -) stable company, the best
# 10  2022  III - (+ -) stable company, the best

# %%
df[['Year-end Yield %','Dividends USD','Change in book value %','Change in Revenue %','Change in Net Income %']]
# Out:
#     Year-end Yield %  Dividends USD  Change in book value %  \
# 0               1.20           0.00                   100.0
# 1               0.45           0.07                    11.0
# 2               0.29           0.31                    -5.0
# 3               0.46           0.34                    15.0
# 4               0.26           0.39                    13.0
# 5               0.57           0.26                    28.0
# 6               0.61           0.57                    -3.0
# 7               0.64           0.61                    59.0
# 8               0.64           0.64                    21.0
# 9               0.00           0.64                    25.0
# 10              0.00           0.64                    11.0
#
#     Change in Revenue %  Change in Net Income %
# 0                 100.0                   100.0
# 1                   7.0                    -3.0
# 2                  -4.0                   -22.0
# 3                  13.0                    43.0
# 4                   7.0                    -3.0
# 5                  38.0                   171.0
# 6                  41.0                    83.0
# 7                  21.0                    36.0
# 8                  -7.0                   -32.0
# 9                  53.0                    55.0
# 10                  0.0                     0.0

# %% [markdown]
# ## The rating of the company

# %%
#Score based on fundamental indicators

def scores(data):
    l=0
    
    #Dyvidend
    if (data['Year-end Yield %'] > 2): l=l+1;
    if (data['Dividends USD'] > 1): l=l+1;
        
    #Book value
    if (data['Change in book value %'] > 0): l=l+1;
    #Increase in sales revenue
    if (data['Change in Revenue %'] > 0): l=l+1;
    #Increase in net income
    if (data['Change in Net Income %'] > 0): l=l+1;
        
    #Profitability
    if (data['ROE %'] > 20): l=l+1;
    if (data['ROA %'] > 10): l=l+1;
    if (data['ROS %'] > 10): l=l+1;
    if (data['OM %'] > 10): l=l+1;
    if (data['NM %'] > 10): l=l+1;
        
    #Liquidity   
    if (data['Current Ratio'] > 2): l=l+1;
    if (data['Cash Ratio %'] > 20): l=l+1;
    if (data['Working capital'] > 0): l=l+1;
        
    #Activity    
    if (data['Cash conversion cycle'] < 0): l=l+1;
        
    #Debt  
    if (data['Longterm Debt/Equity Ratio'] < 20): l=l+1;
    if (data['Debt ratio (Total debt/assets)'] < 67): l=l+1;
        
    #Cash flow description'
    if (data['Cash flow description'] == 'III - (+--) stable company, the best'): l=l+1    
    elif (data['Cash flow description'] == 'VI - (--+) start-up, early stage of activity'): l=l+1
    elif (data['Cash flow description'] == 'VIII - (+-+) after the start-up phase'): l=l+1;
        
    #Property
    if (data['1st degree of coverage'] > 0.6): l=l+1;
        
    return l
        
df['Scores']='0'      
df['Scores']=df.apply(scores, axis=1)

# %% [markdown]
# Rating:
# - 15-18: Very good company
# - 12-14: Good company
# - 9-11: Average company
# - 0-9: Weak company

# %%
#Final evaluation

def rate(score):
    if (score >= 15): return ('Very good company')
    elif (score >= 12): return ('Good company')
    elif (score >= 9): return ('Average company')
    else: return ('Weak company')

df['Rating'] = df['Scores'].apply(rate)

# %%
df[['Date','Scores', 'Rating']]
# Out:
#     Date  Scores             Rating
# 0   2012      14       Good company
# 1   2013      12       Good company
# 2   2014      10    Average company
# 3   2015      13       Good company
# 4   2016      12       Good company
# 5   2017      15  Very good company
# 6   2018      14       Good company
# 7   2019      15  Very good company
# 8   2020      13       Good company
# 9   2021      15  Very good company
# 10  2022      13       Good company

# %% [markdown]
# ## Wykres wskaźników

# %%
plt.figure(figsize=(20,8))
plt.subplot(1, 1, 1)

sns.set(font_scale=1.5, style="whitegrid")
ax = sns.lineplot(x='Date', y='Scores', 
                  data=df, 
                  color='Black', 
                  label = 'Company score:\n\
15-18: Very good company\n\
12-14: Good company\n\
9-11: Average company\n\
0-9: Weak company')

ax.set_title('Company scoring');
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend(frameon=False)

# %%
plt.figure(figsize=(20,8))
plt.subplot(1, 1, 1)

sns.set(font_scale=1.5, style="whitegrid")
ax = sns.lineplot(x='Date', y='Change in Revenue %', 
                  data=df, 
                  color='lightgray', 
                  label = 'Change in Revenue %')
ax = sns.lineplot(x='Date', y='Change in Net Income %', 
                  data=df, 
                  color='darkgray', 
                  label = 'Change in Net Income %')
ax = sns.lineplot(x='Date', y='Change in book value %', 
                  data=df, 
                  color='gray', 
                  label = 'Change in book value %')
ax.set_title('Changes in revenues and earnings');
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend(frameon=False)

# %%
plt.figure(figsize=(20,8))
plt.subplot(1, 1, 1)

sns.set(font_scale=1.5, style="whitegrid")
ax = sns.lineplot(x='Date', y='Year-end Yield %', 
                  data=df, 
                  color='lightgray',
                  label = 'Year-end Yield %')
ax = sns.lineplot(x='Date', y='Dividends USD', 
                  data=df, 
                  color='gray',
                  label = 'Dividends USD per Share')

ax.set_title('Dividend change');
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend(frameon=False)
